# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import *

data = pd.read_csv('wind_speed.csv', sep=',')
data.head()





x = data['10 Min Sampled Avg']
d1 = pd.DataFrame(data={
    'df1': data['10 Min Sampled Avg']
})
d1.plot.kde()

d = d1['df1']
ks_results = kstest(x, 'norm', (d1.mean(), d1.std()), N=5000)
print(ks_results)
# Out:
# KstestResult(statistic=0.09198903447527956, pvalue=0.044520829944371676)
